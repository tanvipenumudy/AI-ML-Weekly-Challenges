# %% [markdown]
# Name - Tanvi Penumudy
#
# EnrollmentNo - E18CSE187

# %% [markdown]
# **Placement prediction for vocational training (short term training)**
#
# Problem statement:
# In this hackthon we will solve the placement prediction problem. Placement prediction has been done in two stage, first at the time of admission, second when training completed and result is availble.
#
# **Prediction at admission time:** In probem 1. column 17(Result) and 18(certificate) will not used as input feature.
#
# **Prediction with result:** In probem 2. both Result and certificate will be included during prediction.
#
# **About Data**
#
#  The feature of the data set are as follows:
# 1. Gender
# 2. agegroup
# 3. EducationLevel
# 4. TypeofDisability
# 5. castecategory
# 6. Religion
# 7. Candidate State
# 8. Candidate District
# 9. PartnerName
# 10. TC State
# 11. TC District
# 12. TC Constituency
# 13. TC Name
# 14. SectorName
# 15. JobRole
# 16. TotalCandidatesinBatch
# 17. Result
# 18. Certified
#
# Target column **placed**
#
# "placed": {"Yes": 1, "No": 2}
#
# All the columns in dataset converted into numbers with label encoding.
#
# You will get four csv file named as
# For probelm 1
#
# 1. trainadmission.csv
# 2. testadmission.csv
#
# For problem2
#
# 3. trainresult.csv
# 4. testresult.csv
#
# Submission or result and code:
#
# you are suppose to submit two csv file:
#
# 1. "enrollmentno"_testadmission.csv
# 2. "enrollmentno"_testresult.csv
#
# 3. "enrollmentno"_hack1.ipynb  (python Notebook/ python file)
#
# both the submission includes placed column in test file at the end.
#
# Best wishes

# %% [markdown]
# ## Problem 1

# %%
#Start your code!!
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split

# %%
# !ls
# Out:
# sample_data	   testresult.csv      trainresult.csv
# testadmission.csv  trainadmission.csv

# %%
d = pd.read_csv('trainadmission.csv')
d
# Out:
#         Unnamed: 0  Gender  TypeofDisability  ...  agegroup  EducationLevel  placed
# 0           124392       1                 1  ...         2               2       2
# 1            99020       1                 1  ...         4               3       1
# 2             1109       2                 1  ...         3               3       1
# 3           131599       2                 1  ...         2               4       1
# 4           113142       1                 1  ...         3               3       1
# ...            ...     ...               ...  ...       ...             ...     ...
# 127495       45039       1                 1  ...         7               3       1
# 127496      145412       1                 1  ...         4               3       1
# 127497      143483       1                 1  ...         6               2       2
# 127498        6500       2                 1  ...         4               3       2
# ...

# %%
df = d.iloc[:,:-1]
mm = MinMaxScaler()
df[:]= mm.fit_transform(df[:])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
df
# Out:
#         Unnamed: 0  Gender  ...  agegroup  EducationLevel
# 0         0.829286     0.0  ...  0.166667             0.2
# 1         0.660138     0.0  ...  0.500000             0.4
# 2         0.007393     1.0  ...  0.333333             0.4
# 3         0.877333     1.0  ...  0.166667             0.6
# 4         0.754285     0.0  ...  0.333333             0.4
# ...            ...     ...  ...       ...             ...
# 127495    0.300262     0.0  ...  1.000000             0.4
# 127496    0.969420     0.0  ...  0.500000             0.4
# 127497    0.956560     0.0  ...  0.833333             0.2
# 127498    0.043334     1.0  ...  0.500000             0.4
# 127499    0.005993     1.0  ...  0.500000             0.2
#
# [127500 rows x 17 columns]

# %%
data = pd.concat([df, d['placed']], axis=1)

# %%
data.head(15)
# Out:
#     Unnamed: 0  Gender  TypeofDisability  ...  agegroup  EducationLevel  placed
# 0     0.829286     0.0               0.0  ...  0.166667             0.2       2
# 1     0.660138     0.0               0.0  ...  0.500000             0.4       1
# 2     0.007393     1.0               0.0  ...  0.333333             0.4       1
# 3     0.877333     1.0               0.0  ...  0.166667             0.6       1
# 4     0.754285     0.0               0.0  ...  0.333333             0.4       1
# 5     0.986000     1.0               0.0  ...  0.500000             1.0       1
# 6     0.784092     0.0               0.0  ...  0.500000             0.8       2
# 7     0.806699     1.0               0.0  ...  0.500000             0.4       2
# 8     0.206021     1.0               0.0  ...  0.333333             0.4       2
# 9     0.295329     1.0               0.0  ...  0.500000             0.2       2
# 10    0.632024     1.0               0.0  ...  0.166667             0.2       1
# ...

# %%
data=data.sample(frac=1).reset_index(drop=True)

# %%
data.head()
# Out:
#    Unnamed: 0  Gender  TypeofDisability  ...  agegroup  EducationLevel  placed
# 0    0.058434     1.0          0.000000  ...  0.166667             0.4       2
# 1    0.218195     1.0          0.000000  ...  0.166667             0.4       2
# 2    0.259182     1.0          0.000000  ...  0.333333             0.4       1
# 3    0.370936     1.0          0.083333  ...  0.666667             0.2       1
# 4    0.078527     0.0          0.000000  ...  0.333333             0.8       1
#
# [5 rows x 18 columns]

# %%
LE = preprocessing.LabelEncoder()
data['placed'] = LE.fit_transform(data['placed'])

# %%
data
# Out:
#         Unnamed: 0  Gender  TypeofDisability  ...  agegroup  EducationLevel  placed
# 0         0.058434     1.0          0.000000  ...  0.166667             0.4       1
# 1         0.218195     1.0          0.000000  ...  0.166667             0.4       1
# 2         0.259182     1.0          0.000000  ...  0.333333             0.4       0
# 3         0.370936     1.0          0.083333  ...  0.666667             0.2       0
# 4         0.078527     0.0          0.000000  ...  0.333333             0.8       0
# ...            ...     ...               ...  ...       ...             ...     ...
# 127495    0.597157     1.0          0.000000  ...  0.666667             0.4       0
# 127496    0.275929     1.0          0.000000  ...  0.166667             0.2       1
# 127497    0.276309     1.0          0.000000  ...  0.166667             0.4       0
# 127498    0.402403     1.0          0.000000  ...  0.333333             0.2       1
# ...

# %%
data['placed'].replace([0,1],[1,0],inplace=True)

# %%
data
# Out:
#         Unnamed: 0  Gender  TypeofDisability  ...  agegroup  EducationLevel  placed
# 0         0.058434     1.0          0.000000  ...  0.166667             0.4       0
# 1         0.218195     1.0          0.000000  ...  0.166667             0.4       0
# 2         0.259182     1.0          0.000000  ...  0.333333             0.4       1
# 3         0.370936     1.0          0.083333  ...  0.666667             0.2       1
# 4         0.078527     0.0          0.000000  ...  0.333333             0.8       1
# ...            ...     ...               ...  ...       ...             ...     ...
# 127495    0.597157     1.0          0.000000  ...  0.666667             0.4       1
# 127496    0.275929     1.0          0.000000  ...  0.166667             0.2       0
# 127497    0.276309     1.0          0.000000  ...  0.166667             0.4       1
# 127498    0.402403     1.0          0.000000  ...  0.333333             0.2       0
# ...

# %%
data.isna().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# TypeofDisability          0
# castecategory             0
# Religion                  0
# Candidate State           0
# Candidate District        0
# PartnerName               0
# TC State                  0
# TC District               0
# TC Constituency           0
# TC Name                   0
# SectorName                0
# JobRole                   0
# TotalCandidatesinBatch    0
# agegroup                  0
# EducationLevel            0
# placed                    0
# dtype: int64

# %%
data.describe()
# Out:
#           Unnamed: 0         Gender  ...  EducationLevel         placed
# count  127500.000000  127500.000000  ...   127500.000000  127500.000000
# mean        0.499901       0.503098  ...        0.386207       0.450133
# std         0.288607       0.499992  ...        0.192655       0.497509
# min         0.000000       0.000000  ...        0.000000       0.000000
# 25%         0.249820       0.000000  ...        0.200000       0.000000
# 50%         0.499953       1.000000  ...        0.400000       0.000000
# 75%         0.749940       1.000000  ...        0.400000       1.000000
# max         1.000000       1.000000  ...        1.000000       1.000000
#
# [8 rows x 18 columns]

# %%
data.cov()
# Out:
#                         Unnamed: 0    Gender  ...  EducationLevel    placed
# Unnamed: 0                0.083294  0.000382  ...       -0.000261  0.000648
# Gender                    0.000382  0.249992  ...        0.004983 -0.008516
# TypeofDisability          0.000018  0.000303  ...       -0.000101 -0.000202
# castecategory             0.000118 -0.008226  ...       -0.000520  0.000056
# Religion                  0.000155 -0.002424  ...        0.000278  0.007297
# Candidate State           0.000215 -0.002651  ...        0.000097 -0.004329
# Candidate District        0.000548 -0.000999  ...        0.001093 -0.004539
# PartnerName               0.001050 -0.004480  ...       -0.000700 -0.002893
# TC State                  0.000225 -0.002592  ...       -0.000012 -0.003980
# TC District               0.000752 -0.001080  ...        0.000053 -0.004074
# TC Constituency           0.000514  0.000592  ...        0.002433 -0.003478
# ...

# %%
data = data.drop(['castecategory'], axis = 1)
data
# Out:
#         Unnamed: 0  Gender  TypeofDisability  ...  agegroup  EducationLevel  placed
# 0         0.058434     1.0          0.000000  ...  0.166667             0.4       0
# 1         0.218195     1.0          0.000000  ...  0.166667             0.4       0
# 2         0.259182     1.0          0.000000  ...  0.333333             0.4       1
# 3         0.370936     1.0          0.083333  ...  0.666667             0.2       1
# 4         0.078527     0.0          0.000000  ...  0.333333             0.8       1
# ...            ...     ...               ...  ...       ...             ...     ...
# 127495    0.597157     1.0          0.000000  ...  0.666667             0.4       1
# 127496    0.275929     1.0          0.000000  ...  0.166667             0.2       0
# 127497    0.276309     1.0          0.000000  ...  0.166667             0.4       1
# 127498    0.402403     1.0          0.000000  ...  0.333333             0.2       0
# ...

# %%
print((data.placed == 0).sum())
print((data.placed == 1).sum())
# Out:
# 70108
# 57392

# %%
import sympy

# %%
#reduced_form, inds = sympy.Matrix(data.values).rref()

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
array = data.values
X = array[:,:-1]
Y = array[:,-1]
print(X.shape, Y.shape)
# feature extraction
model = ExtraTreesClassifier(n_estimators=10)
model.fit(X, Y)
print(model.feature_importances_)
# Out:
# (127500, 16) (127500,)
# [0.21437252 0.01188317 0.00297668 0.05387758 0.03980947 0.06697376
#  0.07682337 0.03907238 0.05961366 0.06092575 0.07948991 0.06108668
#  0.07137352 0.02955532 0.07938775 0.05277846]

# %%
data = data.drop(['TC State'], axis = 1)
data
# Out:
#         Unnamed: 0  Gender  TypeofDisability  ...  agegroup  EducationLevel  placed
# 0         0.058434     1.0          0.000000  ...  0.166667             0.4       0
# 1         0.218195     1.0          0.000000  ...  0.166667             0.4       0
# 2         0.259182     1.0          0.000000  ...  0.333333             0.4       1
# 3         0.370936     1.0          0.083333  ...  0.666667             0.2       1
# 4         0.078527     0.0          0.000000  ...  0.333333             0.8       1
# ...            ...     ...               ...  ...       ...             ...     ...
# 127495    0.597157     1.0          0.000000  ...  0.666667             0.4       1
# 127496    0.275929     1.0          0.000000  ...  0.166667             0.2       0
# 127497    0.276309     1.0          0.000000  ...  0.166667             0.4       1
# 127498    0.402403     1.0          0.000000  ...  0.333333             0.2       0
# ...

# %%
corr = data.corr()

# %%
import seaborn as sns

# %%
sns.heatmap(corr)

# %%
columns = np.full((corr.shape[0],), True, dtype=bool)
for i in range(corr.shape[0]):
    for j in range(i+1, corr.shape[0]):
        if corr.iloc[i,j] >= 0.8:
            if columns[j]:
                columns[j] = False
selected_columns = data.columns[columns]
data = data[selected_columns]

# %%
data
# Out:
#         Unnamed: 0  Gender  TypeofDisability  ...  agegroup  EducationLevel  placed
# 0         0.058434     1.0          0.000000  ...  0.166667             0.4       0
# 1         0.218195     1.0          0.000000  ...  0.166667             0.4       0
# 2         0.259182     1.0          0.000000  ...  0.333333             0.4       1
# 3         0.370936     1.0          0.083333  ...  0.666667             0.2       1
# 4         0.078527     0.0          0.000000  ...  0.333333             0.8       1
# ...            ...     ...               ...  ...       ...             ...     ...
# 127495    0.597157     1.0          0.000000  ...  0.666667             0.4       1
# 127496    0.275929     1.0          0.000000  ...  0.166667             0.2       0
# 127497    0.276309     1.0          0.000000  ...  0.166667             0.4       1
# 127498    0.402403     1.0          0.000000  ...  0.333333             0.2       0
# ...

# %%
X=data.drop(['placed'],axis=1).values
y=data['placed'].values
print(X.shape, y.shape)
# Out:
# (127500, 15) (127500,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=123)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (95625, 15) (31875, 15) (95625,) (31875,)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
input_dim = X.shape[1]
model = Sequential()
model.add(Dense(10, activation='relu', input_dim=input_dim))
model.add(Dense(25, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(75, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_70 (Dense)             (None, 10)                160
# _________________________________________________________________
# dense_71 (Dense)             (None, 25)                275
# _________________________________________________________________
# dense_72 (Dense)             (None, 50)                1300
# _________________________________________________________________
# dense_73 (Dense)             (None, 75)                3825
# _________________________________________________________________
# dense_74 (Dense)             (None, 100)               7600
# _________________________________________________________________
# dense_75 (Dense)             (None, 1)                 101
# ...
# Total params: 13,261
# Trainable params: 13,261
# Non-trainable params: 0
# ...

# %%
history = model.fit(X_train,y_train,
                    epochs=30,
                    verbose=True,
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/30
# 2989/2989 [==============================] - 9s 3ms/step - loss: 5.3731e-08 - accuracy: 0.5444 - val_loss: 5.3447e-08 - val_accuracy: 0.5446
# Epoch 2/30
# 2989/2989 [==============================] - 9s 3ms/step - loss: 5.3731e-08 - accuracy: 0.5444 - val_loss: 5.3447e-08 - val_accuracy: 0.5446
# Epoch 3/30
# 2989/2989 [==============================] - 9s 3ms/step - loss: 5.3731e-08 - accuracy: 0.5444 - val_loss: 5.3447e-08 - val_accuracy: 0.5446
# Epoch 4/30
# 2989/2989 [==============================] - 9s 3ms/step - loss: 5.3731e-08 - accuracy: 0.5444 - val_loss: 5.3447e-08 - val_accuracy: 0.5446
# Epoch 5/30
# 2989/2989 [==============================] - 9s 3ms/step - loss: 5.3731e-08 - accuracy: 0.5444 - val_loss: 5.3447e-08 - val_accuracy: 0.5446
# Epoch 6/30
# 2989/2989 [==============================] - 9s 3ms/step - loss: 5.3731e-08 - accuracy: 0.5444 - val_loss: 5.3447e-08 - val_accuracy: 0.5446
# Epoch 7/30
# ...

# %%
t1 = pd.read_csv('testadmission.csv')

# %%
t1.shape
# Out:
# (22500, 18)

# %%
t1.head()
# Out:
#    Unnamed: 0  Gender  TypeofDisability  ...  agegroup  EducationLevel  placed
# 0       19934       2                 1  ...         3               3     NaN
# 1       58270       2                 1  ...         4               3     NaN
# 2      143862       2                 1  ...         7               2     NaN
# 3       72890       1                 1  ...         3               2     NaN
# 4       83926       1                 1  ...         3               3     NaN
#
# [5 rows x 18 columns]

# %%
t1 = t1.drop(['castecategory','TC State', 'placed'], axis = 1)

# %%
t1.head()
# Out:
#    Unnamed: 0  Gender  ...  agegroup  EducationLevel
# 0       19934       2  ...         3               3
# 1       58270       2  ...         4               3
# 2      143862       2  ...         7               2
# 3       72890       1  ...         3               2
# 4       83926       1  ...         3               3
#
# [5 rows x 15 columns]

# %%
t1.shape
# Out:
# (22500, 15)

# %%
t1[:]= mm.fit_transform(t1[:])
t1.head()
# Out:
#    Unnamed: 0  Gender  ...  agegroup  EducationLevel
# 0    0.132884     1.0  ...  0.333333             0.4
# 1    0.388466     1.0  ...  0.500000             0.4
# 2    0.959099     1.0  ...  1.000000             0.2
# 3    0.485936     0.0  ...  0.333333             0.2
# 4    0.559512     0.0  ...  0.333333             0.4
#
# [5 rows x 15 columns]

# %%
pred = model.predict(t1.values)

# %%
pred
# Out:
# array([[0.49621794],
#        [0.49887487],
#        [0.4976366 ],
#        ...,
#        [0.49792725],
#        [0.4987911 ],
#        [0.49613518]], dtype=float32)

# %%
pred.shape
# Out:
# (22500, 1)

# %%
pred.reshape(22500)
# Out:
# array([0.49621794, 0.49887487, 0.4976366 , ..., 0.49792725, 0.4987911 ,
#        0.49613518], dtype=float32)

# %%
res = []
for i in pred:
  if(i>0.50):
    res.append(1)
  else:
    res.append(2)

# %%
len(res)
# Out:
# 22500

# %%
y = pd.DataFrame(res)

# %%
y
# Out:
#        0
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
# ...   ..
# 22495  2
# 22496  2
# 22497  2
# 22498  2
# 22499  2
#
# [22500 rows x 1 columns]

# %%
y.iloc[:,-1].value_counts()
# Out:
# 2    20037
# 1     2463
# Name: 0, dtype: int64

# %%
y.to_csv('test1.csv')

# %%
# !cp test1.csv "/"

# %% [markdown]
# ## Problem 2

# %%
d = pd.read_csv('trainresult.csv')
d
# Out:
#         Unnamed: 0  Gender  TypeofDisability  ...  agegroup  EducationLevel  placed
# 0            86994       1                 1  ...         6               3       1
# 1           118637       2                 1  ...         2               3       1
# 2           130745       2                 1  ...         6               3       2
# 3           125434       2                 1  ...         2               2       2
# 4            28956       2                 1  ...         3               5       1
# ...            ...     ...               ...  ...       ...             ...     ...
# 127495       79499       1                 1  ...         4               2       1
# 127496       84927       2                 1  ...         4               2       2
# 127497       56300       1                 1  ...         7               3       2
# 127498       41911       2                 1  ...         4               5       2
# ...

# %%
d.shape
# Out:
# (127500, 20)

# %%
df = d.iloc[:,:-1]
mm = MinMaxScaler()
df[:]= mm.fit_transform(df[:])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
df
# Out:
#         Unnamed: 0  Gender  ...  agegroup  EducationLevel
# 0         0.579968     0.0  ...  0.833333             0.4
# 1         0.790924     1.0  ...  0.166667             0.4
# 2         0.871645     1.0  ...  0.833333             0.4
# 3         0.836238     1.0  ...  0.166667             0.2
# 4         0.193043     1.0  ...  0.333333             0.8
# ...            ...     ...  ...       ...             ...
# 127495    0.530000     0.0  ...  0.500000             0.2
# 127496    0.566188     1.0  ...  0.500000             0.2
# 127497    0.375338     0.0  ...  1.000000             0.4
# 127498    0.279410     1.0  ...  0.500000             0.8
# 127499    0.773230     0.0  ...  0.333333             0.4
#
# [127500 rows x 19 columns]

# %%
data = pd.concat([df, d['placed']], axis=1)

# %%
data.head(15)
# Out:
#     Unnamed: 0  Gender  TypeofDisability  ...  agegroup  EducationLevel  placed
# 0     0.579968     0.0               0.0  ...  0.833333             0.4       1
# 1     0.790924     1.0               0.0  ...  0.166667             0.4       1
# 2     0.871645     1.0               0.0  ...  0.833333             0.4       2
# 3     0.836238     1.0               0.0  ...  0.166667             0.2       2
# 4     0.193043     1.0               0.0  ...  0.333333             0.8       1
# 5     0.798724     0.0               0.0  ...  0.000000             0.2       1
# 6     0.516014     1.0               0.0  ...  0.500000             0.2       2
# 7     0.188983     1.0               0.0  ...  0.333333             0.4       2
# 8     0.343051     0.0               0.0  ...  0.333333             0.2       1
# 9     0.936666     0.0               0.0  ...  0.000000             0.4       2
# 10    0.900392     0.0               0.0  ...  0.833333             0.8       2
# ...

# %%
data=data.sample(frac=1).reset_index(drop=True)

# %%
data
# Out:
#         Unnamed: 0  Gender  TypeofDisability  ...  agegroup  EducationLevel  placed
# 0         0.272137     0.0               0.0  ...  0.333333             0.4       1
# 1         0.603641     0.0               0.0  ...  0.666667             0.2       2
# 2         0.808684     0.0               0.0  ...  0.666667             0.2       2
# 3         0.282737     1.0               0.0  ...  0.333333             0.2       2
# 4         0.542867     1.0               0.0  ...  0.833333             0.2       1
# ...            ...     ...               ...  ...       ...             ...     ...
# 127495    0.088441     0.0               0.0  ...  0.333333             0.2       2
# 127496    0.133942     1.0               0.0  ...  0.166667             0.2       2
# 127497    0.529460     1.0               0.0  ...  0.166667             0.4       2
# 127498    0.538927     1.0               0.0  ...  0.166667             0.2       2
# ...

# %%
LE = preprocessing.LabelEncoder()
data['placed'] = LE.fit_transform(data['placed'])

# %%
data.head()
# Out:
#    Unnamed: 0  Gender  TypeofDisability  ...  agegroup  EducationLevel  placed
# 0    0.272137     0.0               0.0  ...  0.333333             0.4       0
# 1    0.603641     0.0               0.0  ...  0.666667             0.2       1
# 2    0.808684     0.0               0.0  ...  0.666667             0.2       1
# 3    0.282737     1.0               0.0  ...  0.333333             0.2       1
# 4    0.542867     1.0               0.0  ...  0.833333             0.2       0
#
# [5 rows x 20 columns]

# %%
data['placed'].replace([0,1],[1,0],inplace=True)

# %%
data.head()
# Out:
#    Unnamed: 0  Gender  TypeofDisability  ...  agegroup  EducationLevel  placed
# 0    0.272137     0.0               0.0  ...  0.333333             0.4       1
# 1    0.603641     0.0               0.0  ...  0.666667             0.2       0
# 2    0.808684     0.0               0.0  ...  0.666667             0.2       0
# 3    0.282737     1.0               0.0  ...  0.333333             0.2       0
# 4    0.542867     1.0               0.0  ...  0.833333             0.2       1
#
# [5 rows x 20 columns]

# %%
print((data.placed == 0).sum())
print((data.placed == 1).sum())
# Out:
# 70012
# 57488

# %%
data.isna().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# TypeofDisability          0
# castecategory             0
# Religion                  0
# Candidate State           0
# Candidate District        0
# PartnerName               0
# TC State                  0
# TC District               0
# TC Constituency           0
# TC Name                   0
# SectorName                0
# JobRole                   0
# TotalCandidatesinBatch    0
# Result                    0
# Certified                 0
# agegroup                  0
# EducationLevel            0
# placed                    0
# dtype: int64

# %%
data.describe()
# Out:
#           Unnamed: 0         Gender  ...  EducationLevel         placed
# count  127500.000000  127500.000000  ...   127500.000000  127500.000000
# mean        0.499895       0.503247  ...        0.386544       0.450886
# std         0.288356       0.499991  ...        0.192831       0.497584
# min         0.000000       0.000000  ...        0.000000       0.000000
# 25%         0.250295       0.000000  ...        0.200000       0.000000
# 50%         0.499967       1.000000  ...        0.400000       0.000000
# 75%         0.749345       1.000000  ...        0.400000       1.000000
# max         1.000000       1.000000  ...        1.000000       1.000000
#
# [8 rows x 20 columns]

# %%
data.cov()
# Out:
#                         Unnamed: 0    Gender  ...  EducationLevel    placed
# Unnamed: 0                0.083149  0.000530  ...       -0.000254  0.000829
# Gender                    0.000530  0.249991  ...        0.004861 -0.008115
# TypeofDisability          0.000014  0.000307  ...       -0.000103 -0.000218
# castecategory             0.000511 -0.008576  ...       -0.000396  0.000252
# Religion                  0.000134 -0.002636  ...        0.000285  0.007254
# Candidate State           0.000179 -0.002612  ...        0.000144 -0.004403
# Candidate District        0.000454 -0.000952  ...        0.001087 -0.004533
# PartnerName               0.001087 -0.004428  ...       -0.000714 -0.002733
# TC State                  0.000134 -0.002633  ...        0.000029 -0.004080
# TC District               0.000731 -0.001254  ...        0.000034 -0.003934
# TC Constituency           0.000428  0.000502  ...        0.002393 -0.003359
# ...

# %%
data = data.drop(['TypeofDisability'], axis=1)

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
array = data.values
X = array[:,:-1]
Y = array[:,-1]
print(X.shape, Y.shape)
# feature extraction
model = ExtraTreesClassifier(n_estimators=10)
model.fit(X, Y)
print(model.feature_importances_)
# Out:
# (127500, 18) (127500,)
# [0.13708541 0.01136107 0.03672559 0.04485197 0.03907542 0.06104134
#  0.07162992 0.03992592 0.05685204 0.05813179 0.07032637 0.05500974
#  0.06276356 0.02789369 0.04366495 0.0811629  0.05842893 0.04406939]

# %%
data = data.drop(['castecategory'], axis=1)

# %%
data.shape
# Out:
# (127500, 18)

# %%
data.head()
# Out:
#    Unnamed: 0  Gender  Religion  ...  agegroup  EducationLevel  placed
# 0    0.272137     0.0     0.250  ...  0.333333             0.4       1
# 1    0.603641     0.0     0.250  ...  0.666667             0.2       0
# 2    0.808684     0.0     0.250  ...  0.666667             0.2       0
# 3    0.282737     1.0     0.250  ...  0.333333             0.2       0
# 4    0.542867     1.0     0.375  ...  0.833333             0.2       1
#
# [5 rows x 18 columns]

# %%
corr = data.corr()
sns.heatmap(corr)

# %%
columns = np.full((corr.shape[0],), True, dtype=bool)
for i in range(corr.shape[0]):
    for j in range(i+1, corr.shape[0]):
        if corr.iloc[i,j] >= 0.90:
            if columns[j]:
                columns[j] = False
selected_columns = data.columns[columns]
data = data[selected_columns]

# %%
data
# Out:
#         Unnamed: 0  Gender  Religion  ...  agegroup  EducationLevel  placed
# 0         0.272137     0.0     0.250  ...  0.333333             0.4       1
# 1         0.603641     0.0     0.250  ...  0.666667             0.2       0
# 2         0.808684     0.0     0.250  ...  0.666667             0.2       0
# 3         0.282737     1.0     0.250  ...  0.333333             0.2       0
# 4         0.542867     1.0     0.375  ...  0.833333             0.2       1
# ...            ...     ...       ...  ...       ...             ...     ...
# 127495    0.088441     0.0     0.375  ...  0.333333             0.2       0
# 127496    0.133942     1.0     0.000  ...  0.166667             0.2       0
# 127497    0.529460     1.0     0.000  ...  0.166667             0.4       0
# 127498    0.538927     1.0     0.250  ...  0.166667             0.2       0
# 127499    0.124035     1.0     0.000  ...  0.166667             0.4       0
#
# [127500 rows x 16 columns]

# %%
X=data.drop(['placed'],axis=1).values
y=data['placed'].values
print(X.shape, y.shape)
# Out:
# (127500, 15) (127500,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=123)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (95625, 15) (31875, 15) (95625,) (31875,)

# %%
input_dim = X.shape[1]
model = Sequential()
model.add(Dense(10, activation='relu', input_dim=input_dim))
model.add(Dense(25, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(75, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(125, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_103 (Dense)            (None, 10)                160
# _________________________________________________________________
# dense_104 (Dense)            (None, 25)                275
# _________________________________________________________________
# dense_105 (Dense)            (None, 50)                1300
# _________________________________________________________________
# dense_106 (Dense)            (None, 75)                3825
# _________________________________________________________________
# dense_107 (Dense)            (None, 100)               7600
# _________________________________________________________________
# dense_108 (Dense)            (None, 125)               12625
# _________________________________________________________________
# dense_109 (Dense)            (None, 1)                 126
# ...

# %%
history = model.fit(X_train,y_train,
                    epochs=30,
                    verbose=True,
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/30
# 2989/2989 [==============================] - 10s 3ms/step - loss: 5.3783e-08 - accuracy: 0.5420 - val_loss: 5.3649e-08 - val_accuracy: 0.5430
# Epoch 2/30
# 2989/2989 [==============================] - 10s 3ms/step - loss: 5.3783e-08 - accuracy: 0.5420 - val_loss: 5.3649e-08 - val_accuracy: 0.5430
# Epoch 3/30
# 2989/2989 [==============================] - 10s 3ms/step - loss: 5.3783e-08 - accuracy: 0.5420 - val_loss: 5.3649e-08 - val_accuracy: 0.5430
# Epoch 4/30
# 2989/2989 [==============================] - 9s 3ms/step - loss: 5.3783e-08 - accuracy: 0.5420 - val_loss: 5.3649e-08 - val_accuracy: 0.5430
# Epoch 5/30
# 2989/2989 [==============================] - 10s 3ms/step - loss: 5.3783e-08 - accuracy: 0.5420 - val_loss: 5.3649e-08 - val_accuracy: 0.5430
# Epoch 6/30
# 2989/2989 [==============================] - 9s 3ms/step - loss: 5.3783e-08 - accuracy: 0.5420 - val_loss: 5.3649e-08 - val_accuracy: 0.5430
# Epoch 7/30
# ...

# %%
t2 = pd.read_csv('testresult.csv')

# %%
t2.shape
# Out:
# (22500, 20)

# %%
t2.head()
# Out:
#    Unnamed: 0  Gender  TypeofDisability  ...  agegroup  EducationLevel  placed
# 0      129459       2                 1  ...         4               5     NaN
# 1      134017       2                 1  ...         2               3     NaN
# 2       86522       2                 1  ...         2               2     NaN
# 3      138465       2                 1  ...         2               2     NaN
# 4      143904       1                 1  ...         3               2     NaN
#
# [5 rows x 20 columns]

# %%
t2 = t2.drop(['castecategory','TC State', 'placed', 'Certified', 'TypeofDisability'], axis = 1)

# %%
t2.head()
# Out:
#    Unnamed: 0  Gender  Religion  ...  Result  agegroup  EducationLevel
# 0      129459       2         4  ...       4         4               5
# 1      134017       2         3  ...       1         2               3
# 2       86522       2         1  ...       4         2               2
# 3      138465       2         7  ...       1         2               2
# 4      143904       1         3  ...       1         3               2
#
# [5 rows x 15 columns]

# %%
t2.shape
# Out:
# (22500, 15)

# %%
t2[:]= mm.fit_transform(t2[:])
t2.head()
# Out:
#    Unnamed: 0  Gender  Religion  ...  Result  agegroup  EducationLevel
# 0    0.863060     1.0     0.375  ...     1.0  0.500000             0.8
# 1    0.893448     1.0     0.250  ...     0.0  0.166667             0.4
# 2    0.576800     1.0     0.000  ...     1.0  0.166667             0.2
# 3    0.923103     1.0     0.750  ...     0.0  0.166667             0.2
# 4    0.959365     0.0     0.250  ...     0.0  0.333333             0.2
#
# [5 rows x 15 columns]

# %%
pred = model.predict(t2.values)

# %%
pred
# Out:
# array([[0.49546388],
#        [0.49867517],
#        [0.49765867],
#        ...,
#        [0.4992998 ],
#        [0.49825457],
#        [0.4982593 ]], dtype=float32)

# %%
pred.shape
# Out:
# (22500, 1)

# %%
pred.reshape(22500)
# Out:
# array([0.49546388, 0.49867517, 0.49765867, ..., 0.4992998 , 0.49825457,
#        0.4982593 ], dtype=float32)

# %%
res = []
for i in pred:
  if(i>0.50):
    res.append(1)
  else:
    res.append(2)

# %%
len(res)
# Out:
# 22500

# %%
y = pd.DataFrame(res)

# %%
y
# Out:
#        0
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
# ...   ..
# 22495  2
# 22496  2
# 22497  2
# 22498  2
# 22499  2
#
# [22500 rows x 1 columns]

# %%
y.iloc[:,-1].value_counts()
# Out:
# 2    21586
# 1      914
# Name: 0, dtype: int64

# %%
y.to_csv('test2.csv')

# %%
# !cp test2.csv "/"
